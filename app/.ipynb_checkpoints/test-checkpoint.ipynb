# %%
import pandas as pd

# %%
df_csv = pd.read_csv("production_2025_10.csv")

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 1 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   date;turbin_id;energie_kWh;arret_planifie;arret_non_planifie  62 non-null     object
# dtypes: object(1)
# memory usage: 624.0+ bytes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_csv = pd.read_csv("combined_data.csv", sep=";")

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                           --------------  -----
#  0   ,turbine_id,model,power_mw,commissioning_date,sensor_id,sensor_type,installation_dt,location_desc,meas_id,ts_utc,wind_speed_mps,temperature_k,vibration_mm_s,consumption_kwh,date,energie_kWh,arret_planifie,arret_non_planifie  200 non-null    object
# dtypes: object(1)
# memory usage: 1.7+ KB

# %%
# segmentation de la donnée entre données de tests et d'entraînement
# from sklearn.model_selection import train_test_split

# X = data.drop(['median_house_value'], axis=1)
# y = data['median_house_value']

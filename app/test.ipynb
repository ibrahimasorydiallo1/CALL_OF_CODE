# %%
import pandas as pd

# %%
df_csv = pd.read_csv("production_2025_10.csv", sep=";")

# %%
df_csv.dropna(inplace=True)

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 0 to 61
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                58 non-null     object
#  1   turbin_id           58 non-null     object
#  2   energie_kWh         58 non-null     float64
#  3   arret_planifie      58 non-null     float64
#  4   arret_non_planifie  58 non-null     int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 2.7+ KB
